# %%
# %%time
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('Images/Gaming-Carbon-Pro.jpg')
plt.imshow(img)
# Out:
# CPU times: total: 172 ms
# Wall time: 526 ms

# %%
from skimage import io
import pandas as pd
img = cv2.imread('Images/Gaming-Carbon-Pro.jpg')
df = pd.DataFrame (img.flatten())
# filePath = 'pixel_value.xlsx'
# df.to_excel(filePath, index=False)

# %%
df.info()
df.head(10)

# %%
df.tail(10)

# %%
df.sample(8)
